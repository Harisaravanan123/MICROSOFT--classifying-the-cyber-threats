# 1484011 -0.024789  0.046688  0.590381 -0.061006  0.362121  0.483286 -0.023315
# 1484012  0.075585  0.306687 -0.188797 -0.060180  0.007225 -0.381385  0.050181
# 1484013 -0.120691  0.162869  0.533977 -0.241260 -0.054207 -0.427749  0.016167
# 1484014 -0.024789  0.046688  0.590381 -0.061006  0.362121  0.483286 -0.023315
# 1484015  1.213504 -3.235373 -1.029420  1.618468 -0.940088  0.092853  0.088585
#
# [1484016 rows x 55 columns]

# %%
# I am going to use stratified k-fold cross validation to eliminate the sampling bias in train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score
k_folds = StratifiedKFold(n_splits=10,shuffle=True,random_state=42)

for train_index,test_index in k_folds.split(X,Y):
    x_train,x_test = X.iloc[train_index],X.iloc[test_index]
    y_train,y_test = Y.iloc[train_index],Y.iloc[test_index]

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=2000)
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
lr_predict = lr.predict(x_test)

# %%
lr_prob = lr.predict_proba(x_test)
lr_prob
# Out:
# array([[5.34491254e-01, 3.10096069e-01, 1.55412677e-01],
#        [3.23697095e-01, 3.26363249e-01, 3.49939656e-01],
#        [6.10498853e-01, 3.44766310e-01, 4.47348362e-02],
#        ...,
#        [5.53519551e-01, 2.66251537e-01, 1.80228912e-01],
#        [3.42304297e-08, 3.07521235e-04, 9.99692445e-01],
#        [4.01686561e-01, 2.05435760e-01, 3.92877679e-01]],
#       shape=(148401, 3))

# %%
lr.classes_
# Out:
# array([0, 1, 2])

# %%
from sklearn.metrics import roc_curve,roc_auc_score
import matplotlib.pyplot as plt
import numpy as np
tpr={}
fpr ={}
roc_auc={}
for i in range(np.array(lr.classes_).shape[0]):
    fpr[i],tpr[i],_ = roc_curve(y_test==i,lr_prob[:,i])
    roc_auc[i] = roc_auc_score(y_test==i,lr_prob[:,i])
plt.figure()  
for i in range(np.array(lr.classes_).shape[0]):
    plt.plot(fpr[i],tpr[i],label=f'ROC curve for class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0,1],[0,1],'k--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("FALSE POSITIVE RATE")
plt.ylabel("TRUE POSITIVE RATE")
plt.title("Multi-class ROC curve")
plt.legend(loc='best')  
plt.show()

# %%
from sklearn.metrics import classification_report,accuracy_score
logisticreg = classification_report(y_test,lr_predict)
print(logisticreg)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.79      0.61     49476
#            1       0.54      0.40      0.46     49453
#            2       0.65      0.45      0.53     49472
#
#     accuracy                           0.54    148401
#    macro avg       0.56      0.54      0.53    148401
# weighted avg       0.56      0.54      0.53    148401

# %%
import pickle
with open('lr.pkl','wb')as model1:
    pickle.dump(lr,model1)

# %% [markdown]
# **DECISION TREE CLASSIFIER**

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc_pred = dtc.predict(x_test)
dtc_prob = dtc.predict_proba(x_test)

# %%
from sklearn.metrics import roc_curve,roc_auc_score
import matplotlib.pyplot as plt
tpr={}
fpr ={}
roc_auc={}
for i in range(dtc.classes_.shape[0]):
    fpr[i],tpr[i],_ = roc_curve(y_test == i,dtc_prob[:,i])
    roc_auc[i] = roc_auc_score(y_test == i,dtc_prob[:,i])
plt.figure()  
for i in range(dtc.classes_.shape[0]):
    plt.plot(fpr[i],tpr[i],label=f'ROC curve for class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0,1],[0,1],'k--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("FALSE POSITIVE RATE")
plt.ylabel("TRUE POSITIVE RATE")
plt.title("Multi-class ROC curve for decision tree classifier")
plt.legend(loc='best')  
plt.show()

# %%
dtc_metrics = classification_report(y_test,dtc_pred)
print(dtc_metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.79      0.63     49476
#            1       0.69      0.38      0.49     49453
#            2       0.64      0.60      0.62     49472
#
#     accuracy                           0.59    148401
#    macro avg       0.62      0.59      0.58    148401
# weighted avg       0.62      0.59      0.58    148401

# %%
import pickle
with open('dtc.pkl','wb')as model2:
    pickle.dump(dtc,model2)

# %% [markdown]
# **RANDOM FOREST CLASSIFIER**

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rfc_pred = rfc.predict(x_test)
rfc_proba = rfc.predict_proba(x_test)

# %%
from sklearn.metrics import roc_curve,roc_auc_score
import matplotlib.pyplot as plt
tpr={}
fpr ={}
roc_auc={}
for i in range(rfc.classes_.shape[0]):
    fpr[i],tpr[i],_ = roc_curve(y_test == i,rfc_proba[:,i])
    roc_auc[i] = roc_auc_score(y_test == i,rfc_proba[:,i])
plt.figure()  
for i in range(rfc.classes_.shape[0]):
    plt.plot(fpr[i],tpr[i],label=f'ROC curve for class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0,1],[0,1],'k--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("FALSE POSITIVE RATE")
plt.ylabel("TRUE POSITIVE RATE")
plt.title("Multi-class ROC curve for RANDOM FOREST CLASSIFIER")
plt.legend(loc='best')  
plt.show()

# %%
from sklearn.metrics import classification_report
rfc_report = classification_report(y_test,rfc_pred)
print(rfc_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.79      0.63     49476
#            1       0.69      0.38      0.49     49453
#            2       0.64      0.60      0.62     49472
#
#     accuracy                           0.59    148401
#    macro avg       0.62      0.59      0.58    148401
# weighted avg       0.62      0.59      0.58    148401

# %%
import pickle
with open('rfc.pkl','wb')as model3:
    pickle.dump(rfc,model3)

# %% [markdown]
# GRADIENT BOOSTING CLASSIFIER

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
gbc_pred = gbc.predict(x_test)
gbc_prob = gbc.predict_proba(x_test)

# %%
from sklearn.metrics import roc_curve,roc_auc_score
import matplotlib.pyplot as plt
tpr={}
fpr ={}
roc_auc={}
for i in range(gbc.classes_.shape[0]):
    fpr[i],tpr[i],_ = roc_curve(y_test == i,gbc_prob[:,i])
    roc_auc[i] = roc_auc_score(y_test == i,gbc_prob[:,i])
plt.figure()  
for i in range(gbc.classes_.shape[0]):
    plt.plot(fpr[i],tpr[i],label=f'ROC curve for class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0,1],[0,1],'k--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("FALSE POSITIVE RATE")
plt.ylabel("TRUE POSITIVE RATE")
plt.title("Multi-class ROC curve for GRADIENT BOOSTING CLASSIFIER")
plt.legend(loc='best')  
plt.show()

# %%
gbc_report = classification_report(y_test,gbc_pred)
print(gbc_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.79      0.63     49476
#            1       0.70      0.37      0.48     49453
#            2       0.63      0.60      0.62     49472
#
#     accuracy                           0.59    148401
#    macro avg       0.62      0.59      0.58    148401
# weighted avg       0.62      0.59      0.58    148401

# %%
import pickle
with open('gbc.pkl','wb')as model4:
    pickle.dump(gbc,model4)

# %% [markdown]
# EXTREME GRADIENT BOOSTING

# %%
import xgboost as xgb
xgb_classifier = xgb.XGBClassifier()
xgb_classifier.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
xgb_pred = xgb_classifier.predict(x_test)
xgb_prob = xgb_classifier.predict_proba(x_test)

# %%
from sklearn.metrics import roc_curve,roc_auc_score
import matplotlib.pyplot as plt
tpr={}
fpr ={}
roc_auc={}
for i in range(xgb_classifier.classes_.shape[0]):
    fpr[i],tpr[i],_ = roc_curve(y_test == i,xgb_prob[:,i])
    roc_auc[i] = roc_auc_score(y_test == i,xgb_prob[:,i])
plt.figure()  
for i in range(xgb_classifier.classes_.shape[0]):
    plt.plot(fpr[i],tpr[i],label=f'ROC curve for class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0,1],[0,1],'k--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("FALSE POSITIVE RATE")
plt.ylabel("TRUE POSITIVE RATE")
plt.title("Multi-class ROC curve for EXTREME GRADIENT BOOSTING CLASSIFIER")
plt.legend(loc='best')  
plt.show()

# %%
XGB_REPORT = classification_report(y_test,xgb_pred)
print(XGB_REPORT)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.79      0.63     49476
#            1       0.69      0.38      0.49     49453
#            2       0.64      0.60      0.62     49472
#
#     accuracy                           0.59    148401
#    macro avg       0.62      0.59      0.58    148401
# weighted avg       0.62      0.59      0.58    148401

# %%
with open('xgb_classifier.pkl','wb')as model5:
    pickle.dump(xgb_classifier,model5)

# %% [markdown]
# **TESTING DATASET**

# %%
import pandas as pd
df_test = pd.read_csv('pca_test.csv')

# %%
df_test.drop(columns='Unnamed: 0',inplace=True)

# %%
x= df_test.drop(columns='IncidentGrade')
y = df_test['IncidentGrade']

# %% [markdown]
# **LOGISITIC REGRESSION**

# %%
import pickle 
with open('lr.pkl','rb')as model1:
    lr = pickle.load(model1)

# %%
lr
# Out:
# LogisticRegression(max_iter=2000)

# %%
lr_predict_test = lr.predict(x)

# %%
lr_prob_test = lr.predict_proba(x)
lr_prob_test
# Out:
# array([[4.01686561e-01, 2.05435760e-01, 3.92877679e-01],
#        [6.20960208e-01, 3.13633924e-01, 6.54058681e-02],
#        [4.01686561e-01, 2.05435760e-01, 3.92877679e-01],
#        ...,
#        [2.44807150e-02, 5.42001520e-01, 4.33517765e-01],
#        [3.23697095e-01, 3.26363249e-01, 3.49939656e-01],
#        [1.94745530e-07, 8.05605100e-03, 9.91943754e-01]],
#       shape=(1500000, 3))

# %%
from sklearn.metrics import roc_curve,roc_auc_score
import matplotlib.pyplot as plt
import numpy as np
tpr={}
fpr ={}
roc_auc={}
for i in range(np.array(lr.classes_).shape[0]):
    fpr[i],tpr[i],_ = roc_curve(y==i,lr_prob_test[:,i])
    roc_auc[i] = roc_auc_score(y==i,lr_prob_test[:,i])
plt.figure()  
for i in range(np.array(lr.classes_).shape[0]):
    plt.plot(fpr[i],tpr[i],label=f'ROC curve for class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0,1],[0,1],'k--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("FALSE POSITIVE RATE")
plt.ylabel("TRUE POSITIVE RATE")
plt.title("Multi-class ROC curve")
plt.legend(loc='best')  
plt.show()

# %%
from sklearn.metrics import classification_report
lr_test_metrics = classification_report(y,lr_predict_test)
print(lr_test_metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.78      0.62    500000
#            1       0.53      0.43      0.48    500000
#            2       0.65      0.44      0.52    500000
#
#     accuracy                           0.55   1500000
#    macro avg       0.57      0.55      0.54   1500000
# weighted avg       0.57      0.55      0.54   1500000

# %% [markdown]
# **DECISION TREE CLASSIFIER**

# %%
with open('dtc.pkl','rb')as model2:
    dtc_test = pickle.load(model2)

# %%
dtc_test
# Out:
# DecisionTreeClassifier()

# %%
dtc_pred_test = dtc_test.predict(x)
dtc_prob_test = dtc_test.predict_proba(x)

# %%
from sklearn.metrics import roc_curve,roc_auc_score
import matplotlib.pyplot as plt
tpr={}
fpr ={}
roc_auc={}
for i in range(dtc_test.classes_.shape[0]):
    fpr[i],tpr[i],_ = roc_curve(y == i,dtc_prob_test[:,i])
    roc_auc[i] = roc_auc_score(y == i,dtc_prob_test[:,i])
plt.figure()  
for i in range(dtc_test.classes_.shape[0]):
    plt.plot(fpr[i],tpr[i],label=f'ROC curve for class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0,1],[0,1],'k--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("FALSE POSITIVE RATE")
plt.ylabel("TRUE POSITIVE RATE")
plt.title("Multi-class ROC curve for decision tree classifier")
plt.legend(loc='best')  
plt.show()

# %%
from sklearn.metrics import classification_report
dtc_test_metrics = classification_report(y,dtc_pred_test)
print(dtc_test_metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.79      0.64    500000
#            1       0.69      0.41      0.52    500000
#            2       0.64      0.61      0.63    500000
#
#     accuracy                           0.60   1500000
#    macro avg       0.62      0.60      0.59   1500000
# weighted avg       0.62      0.60      0.59   1500000

# %% [markdown]
# **RANDOM FOREST CLASSIFIER**

# %%
with open ('rfc.pkl','rb')as model3:
    rfc_test = pickle.load(model3)

# %%
rfc_test
# Out:
# RandomForestClassifier()

# %%
rfc_pred_test = rfc_test.predict(x)
rfc_prob_test = rfc_test.predict_proba(x)

# %%
from sklearn.metrics import roc_curve,roc_auc_score
import matplotlib.pyplot as plt
tpr={}
fpr ={}
roc_auc={}
for i in range(rfc_test.classes_.shape[0]):
    fpr[i],tpr[i],_ = roc_curve(y == i,rfc_prob_test[:,i])
    roc_auc[i] = roc_auc_score(y == i,rfc_prob_test[:,i])
plt.figure()  
for i in range(rfc_test.classes_.shape[0]):
    plt.plot(fpr[i],tpr[i],label=f'ROC curve for class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0,1],[0,1],'k--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("FALSE POSITIVE RATE")
plt.ylabel("TRUE POSITIVE RATE")
plt.title("Multi-class ROC curve for RANDOM FOREST CLASSIFIER")
plt.legend(loc='best')  
plt.show()

# %%
from sklearn.metrics import classification_report
rfc_test_metrics = classification_report(y,rfc_pred_test)
print(rfc_test_metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.79      0.64    500000
#            1       0.69      0.41      0.52    500000
#            2       0.64      0.61      0.63    500000
#
#     accuracy                           0.60   1500000
#    macro avg       0.62      0.60      0.59   1500000
# weighted avg       0.62      0.60      0.59   1500000

# %% [markdown]
# **GRADIENT BOOSTING CLASSIFIER**

# %%
with open('gbc.pkl','rb')as model4:
    gbc_test = pickle.load(model4)

# %%
gbc_test
# Out:
# GradientBoostingClassifier()

# %%
gbc_pred_test = gbc_test.predict(x)
gbc_prob_test = gbc_test.predict_proba(x)

# %%
from sklearn.metrics import roc_curve,roc_auc_score
import matplotlib.pyplot as plt
tpr={}
fpr ={}
roc_auc={}
for i in range(gbc_test.classes_.shape[0]):
    fpr[i],tpr[i],_ = roc_curve(y == i,gbc_prob_test[:,i])
    roc_auc[i] = roc_auc_score(y == i,gbc_prob_test[:,i])
plt.figure()  
for i in range(gbc_test.classes_.shape[0]):
    plt.plot(fpr[i],tpr[i],label=f'ROC curve for class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0,1],[0,1],'k--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("FALSE POSITIVE RATE")
plt.ylabel("TRUE POSITIVE RATE")
plt.title("Multi-class ROC curve for GRADIENT BOOSTING CLASSIFIER")
plt.legend(loc='best')  
plt.show()

# %%
from sklearn.metrics import classification_report
gbc_test_metrics = classification_report(y,gbc_pred_test)
print(gbc_test_metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.79      0.64    500000
#            1       0.69      0.39      0.50    500000
#            2       0.63      0.62      0.62    500000
#
#     accuracy                           0.60   1500000
#    macro avg       0.62      0.60      0.59   1500000
# weighted avg       0.62      0.60      0.59   1500000

# %% [markdown]
# **XTREME GRADIENT BOOSTING ALGORITHM**

# %%
with open('xgb_classifier.pkl','rb')as model5:
    xgbc_test = pickle.load(model5)

# %%
xgbc_test
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
xgbc_pred_test = xgbc_test.predict(x)
xgbc_prob_test =xgbc_test.predict_proba(x)

# %%
from sklearn.metrics import roc_curve,roc_auc_score
import matplotlib.pyplot as plt
tpr={}
fpr ={}
roc_auc={}
for i in range(xgbc_test.classes_.shape[0]):
    fpr[i],tpr[i],_ = roc_curve(y == i,xgbc_prob_test[:,i])
    roc_auc[i] = roc_auc_score(y == i,xgbc_prob_test[:,i])
plt.figure()  
for i in range(xgbc_test.classes_.shape[0]):
    plt.plot(fpr[i],tpr[i],label=f'ROC curve for class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0,1],[0,1],'k--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("FALSE POSITIVE RATE")
plt.ylabel("TRUE POSITIVE RATE")
plt.title("Multi-class ROC curve for EXTREME GRADIENT BOOSTING CLASSIFIER")
plt.legend(loc='best')  
plt.show()

# %%
from sklearn.metrics import classification_report
xgbc_test_metrics = classification_report(y,xgbc_pred_test)
print(xgbc_test_metrics)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.79      0.64    500000
#            1       0.69      0.41      0.51    500000
#            2       0.64      0.61      0.63    500000
#
#     accuracy                           0.60   1500000
#    macro avg       0.62      0.60      0.59   1500000
# weighted avg       0.62      0.60      0.59   1500000
